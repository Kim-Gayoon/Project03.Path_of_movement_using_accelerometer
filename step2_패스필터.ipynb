# %%
import pandas as pd
import matplotlib.pyplot as plt
import scipy as sp
from scipy import signal
from scipy.stats import norm

# %%
df1 = pd.read_csv('/content/Tr_Accelerometer(2).csv')     # csv 읽어오기
df1
# Out:
#             time  seconds_elapsed         z         y         x  Unnamed: 5  \
# 0   1.671420e+18         0.195983  0.000000  0.000000  0.000000         NaN
# 1   1.671420e+18         0.297701 -0.064709 -0.009822  0.001054         NaN
# 2   1.671420e+18         0.399418 -0.029765 -0.008658  0.017916         NaN
# 3   1.671420e+18         0.501135 -0.021361 -0.004553 -0.002636         NaN
# 4   1.671420e+18         0.602852 -0.017267 -0.004863  0.008293         NaN
# 5   1.671420e+18         0.704570 -0.011146 -0.005478  0.009679         NaN
# 6   1.671420e+18         0.806287 -0.016958  0.001174 -0.010889         NaN
# 7   1.671420e+18         0.908004 -0.010035  0.002413  0.012521         NaN
# 8   1.671420e+18         1.009721 -0.012145  0.001856  0.001258         NaN
# 9   1.671420e+18         1.111438 -0.010190  0.001698 -0.000906         NaN
# 10  1.671420e+18         1.213156 -0.004773  0.001407  0.011107         NaN
# 11  1.671420e+18         1.314873 -0.005003  0.008411 -0.003453         NaN
# 12  1.671420e+18         1.416590 -0.007760  0.002210 -0.002958         NaN
# 13  1.671420e+18         1.518307 -0.004551  0.003401  0.010227         NaN
# 14  1.671420e+18         1.620025 -0.006998  0.008183 -0.009242         NaN
# 15  1.671420e+18         1.721742 -0.000144 -0.024245  0.009452         NaN
# 16  1.671420e+18         1.823459  0.060709 -0.147379 -0.024689         NaN
# 17  1.671420e+18         1.925176 -0.088040  0.014231  0.026381         NaN
# 18  1.671420e+18         2.026894  0.001432  0.030538  0.004253         NaN
# 19  1.671420e+18         2.128611 -0.004146  0.195440 -0.532727         NaN
# 20  1.671420e+18         2.230328  0.005433  0.017348 -0.775426         NaN
# 21  1.671420e+18         2.332045 -0.099351  0.523286 -0.467026         NaN
# 22  1.671420e+18         2.433762  0.075977  0.532619  0.158755         NaN
# 23  1.671420e+18         2.535480 -0.078517  0.578763  0.899466         NaN
# 24  1.671420e+18         2.637197  0.010977  0.144895  1.426935         NaN
# 25  1.671420e+18         2.738914 -0.008171 -0.428726  1.130772         NaN
# 26  1.671420e+18         2.840632  0.132026 -0.850088  0.931347         NaN
# 27  1.671420e+18         2.942349  0.015008 -0.385096  0.338279         NaN
# 28  1.671420e+18         3.044066 -0.002701 -0.713528  0.078677         NaN
# 29  1.671420e+18         3.145783 -0.014894 -0.607786  0.010930         NaN
# 30  1.671420e+18         3.247500  0.124763 -0.507680  0.072567         NaN
# 31  1.671420e+18         3.349218 -0.116609 -0.222536  0.177462         NaN
# 32  1.671420e+18         3.450935  0.072233 -0.121291 -0.079721         NaN
# 33  1.671420e+18         3.552652 -0.084887  0.060483 -0.971804         NaN
# 34  1.671420e+18         3.654370  0.014552 -0.183290 -0.269799         NaN
# 35  1.671420e+18         3.756087  0.159682  0.132725  0.694223         NaN
# 36  1.671420e+18         3.857804 -0.090901  0.143814 -0.852138         NaN
# 37  1.671420e+18         3.959521 -0.069084  0.085425 -0.615312         NaN
# 38  1.671420e+18         4.061239  0.015455  0.111930 -0.829776         NaN
# 39  1.671420e+18         4.162956  0.007738  0.553964 -0.454747         NaN
# 40  1.671420e+18         4.264673 -0.086226  0.574052 -0.252234         NaN
# 41  1.671420e+18         4.366390  0.087955  0.498301 -0.203732         NaN
# 42  1.671420e+18         4.468107 -0.011096  0.236981  0.461947         NaN
# 43  1.671420e+18         4.569824 -0.014705  0.028896  1.429328         NaN
# 44  1.671420e+18         4.671542  0.030312 -0.161467  0.997669         NaN
# 45  1.671420e+18         4.773259 -0.222139 -0.017596  0.285473         NaN
# 46  1.671420e+18         4.874976  0.152373 -0.045198 -0.057466         NaN
# 47  1.671420e+18         4.976694  0.009375 -0.043026  0.093658         NaN
# 48  1.671420e+18         5.078411 -0.012575 -0.030975  0.062754         NaN
# 49  1.671420e+18         5.180128 -0.009315 -0.013376  0.030501         NaN
# 50  1.671420e+18         5.281845 -0.002816 -0.020915  0.068466         NaN
#
#     Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  Unnamed: 10
# 0          NaN    0.000000    0.000000    0.000000     0.000000
# 1          NaN    0.000054   -0.000500    0.000003    -0.000025
# 2          NaN    0.001018   -0.001439    0.000057    -0.000124
# 3          NaN    0.001796   -0.002111    0.000200    -0.000305
# 4          NaN    0.002083   -0.002590    0.000398    -0.000544
# 5          NaN    0.002997   -0.003116    0.000656    -0.000834
# 6          NaN    0.002936   -0.003335    0.000958    -0.001162
# 7          NaN    0.003019   -0.003153    0.001261    -0.001492
# 8          NaN    0.003720   -0.002935    0.001603    -0.001802
# 9          NaN    0.003737   -0.002755    0.001983    -0.002091
# 10         NaN    0.004256   -0.002597    0.002389    -0.002363
# 11         NaN    0.004646   -0.002097    0.002842    -0.002602
# 12         NaN    0.004319   -0.001557    0.003298    -0.002788
# 13         NaN    0.004689   -0.001272    0.003756    -0.002932
# 14         NaN    0.004739   -0.000683    0.004235    -0.003031
# 15         NaN    0.004750   -0.001500    0.004718    -0.003142
# 16         NaN    0.003975   -0.010228    0.005162    -0.003739
# 17         NaN    0.004061   -0.017000    0.005571    -0.005123
# 18         NaN    0.005619   -0.014723    0.006063    -0.006737
# 19         NaN   -0.021258   -0.003230    0.005267    -0.007650
# 20         NaN   -0.087789    0.007592   -0.000279    -0.007428
# 21         NaN   -0.150979    0.035088   -0.012422    -0.005257
# 22         NaN   -0.166657    0.088790   -0.028576     0.001043
# 23         NaN   -0.112837    0.145313   -0.042791     0.012949
# 24         NaN    0.005480    0.182117   -0.048251     0.029602
# 25         NaN    0.135562    0.167682   -0.041078     0.047392
# 26         NaN    0.240438    0.102643   -0.021955     0.061140
# 27         NaN    0.305010    0.039823    0.005786     0.068386
# 28         NaN    0.326216   -0.016051    0.037889     0.069595
# 29         NaN    0.330773   -0.083251    0.071302     0.064545
# 30         NaN    0.335019   -0.139982    0.105164     0.053191
# 31         NaN    0.347736   -0.177120    0.139888     0.037064
# 32         NaN    0.352707   -0.194607    0.175511     0.018158
# 33         NaN    0.299228   -0.197699    0.208668    -0.001794
# 34         NaN    0.236081   -0.203945    0.235893    -0.022221
# 35         NaN    0.257667   -0.206517    0.261004    -0.043096
# 36         NaN    0.249635   -0.192452    0.286805    -0.063387
# 37         NaN    0.175003   -0.180793    0.308401    -0.082370
# 38         NaN    0.101508   -0.170756    0.322464    -0.100249
# 39         NaN    0.036179   -0.136890    0.329467    -0.115896
# 40         NaN    0.000223   -0.079520    0.331318    -0.126902
# 41         NaN   -0.022967   -0.024982    0.330161    -0.132217
# 42         NaN   -0.009835    0.012414    0.328493    -0.132856
# 43         NaN    0.086353    0.025936    0.332385    -0.130906
# 44         NaN    0.209787    0.019193    0.347446    -0.128611
# 45         NaN    0.275045    0.010086    0.372104    -0.127121
# 46         NaN    0.286642    0.006893    0.400671    -0.126258
# 47         NaN    0.288482    0.002406    0.429921    -0.125785
# 48         NaN    0.296437   -0.001358    0.459669    -0.125732
# 49         NaN    0.301180   -0.003613    0.490063    -0.125985
# 50         NaN    0.306213   -0.005357    0.520954    -0.126441

# %%
df2 = df1.loc[:, ['seconds_elapsed', 'y', 'x']]  # 필요한 데이터만 추출

# %%
df_t = list(df2['seconds_elapsed'])  # time_data to list
list_x = list(df2['x'])
list_y = list(df2['y'])

# %%
def df_integral(data):  # 수치적분, 사다리꼴적분 가속도 -> 속도 -> 거리
    result = [0]

    for i in range(len(data) - 1):
        n = result[i] + ((data[i + 1] + data[i]) * (df_t[i + 1] - df_t[i]) / 2)  # 수치적분, 사다리꼴적분
        result.append(round(n, 7))
    return result

# %%
# def df_rect(y, x)
#     N = len(x) -1

# f1 = 0.6/10
# f2 = 3/10
#
# b, a = signal.butter(10,[f1, f2], btype='bandpass')

# %%
b, a = signal.butter(2, 0.1, btype='lowpass')

# %%
list_x = signal.lfilter(b, a, list_x)
list_y = signal.lfilter(b, a, list_y)

# %%
x_2 = df_integral(list_x)  # x 가속도 -> 속도
x_3 = df_integral(x_2)  # x 속도 -> 거리

y_2 = df_integral(list_y)  # y 가속도 - > 속도
y_3 = df_integral(y_2)  # y 속도 -> 거리

# %%
df_scatter = pd.DataFrame(zip(x_3, y_3), columns=['m_y', 'm_x'])  # 리스트 열단위 데이터프레임화

# %%
plt.scatter(df_scatter['m_x'], df_scatter['m_y'])
plt.plot(df_scatter['m_x'], df_scatter['m_y'])
plt.show()  # 플로팅
